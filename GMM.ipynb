# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs

# %%
# 1. Generate synthetic data
X, y_true = make_blobs(n_samples=500, centers=3, cluster_std=0.60, random_state=0)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:, 0], X[:, 1])
plt.title("Synthetic Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
# Out:
# Text(0, 0.5, 'Feature 2')

# %%
gmm = GaussianMixture(n_components=3, covariance_type='full', random_state=42)
gmm.fit(X)
labels = gmm.predict(X)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')
plt.title("Gaussian Mixture Model Clustering", fontsize=14)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
centers = gmm.means_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, marker='X', label='Cluster Centers')
plt.legend()
plt.show()

# %%
print("Cluster Means:\n", gmm.means_)
print("\nCovariances:\n", gmm.covariances_)
# Out:
# Cluster Means:
#  [[ 1.97717414  0.79911732]
#  [-1.52066063  2.93117022]
#  [ 0.90669674  4.34486161]]
#
# Covariances:
#  [[[ 0.35159348  0.03508748]
#   [ 0.03508748  0.34897549]]
#
#  [[ 0.30276907 -0.01566991]
#   [-0.01566991  0.36070643]]
#
#  [[ 0.357183   -0.03027235]
#   [-0.03027235  0.35119566]]]
