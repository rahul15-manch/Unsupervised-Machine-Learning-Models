# %%
from sklearn.cluster  import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import numpy as np  
import pandas as pd

# %%
X,y= make_moons(n_samples=1000, noise=0.05, random_state=42)
plt.scatter(X[:, 0], X[:, 1])

# %%
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.59996716,  0.31757343],
#        [ 0.55020965, -1.42528284],
#        [ 0.46649751, -1.26036633],
#        ...,
#        [ 1.34062188, -1.12206783],
#        [-1.66269509,  0.15973526],
#        [ 0.33988947,  0.72397143]], shape=(1000, 2))

# %%
DBSCAN_model = DBSCAN(eps=0.2, min_samples=5)
DBSCAN_model.fit(X_scaled)
# Out:
# DBSCAN(eps=0.2)

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=DBSCAN_model.labels_, cmap='viridis')
